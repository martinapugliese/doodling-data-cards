# %%
# Imports and settings

import sys
sys.path.append('../')

from common.setups import *
from common.fit_helpers import fit_powlaw

from datetime import datetime
import numpy as np
from os import environ
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
import json

data_folder = 'data/'

plot_color= '#FF8000'

config_ipython()
setup_matplotlib(use_ggplot=False)
set_css_style()
# Out:
# <style>
#
#     /* DOWNLOAD COMPUTER MODERN FONT JUST IN CASE */
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
#     }
#
#     /* GLOBAL TEXT FONT */
#     div#notebook,
#     div.output_area pre,
#     div.output_wrapper,
#     div.prompt {
#       font-family: Times new Roman, monospace !important;
#     }
#
#     /* CENTER FIGURE */
#     .output_png {
#         display: table-cell;
#         text-align: center;
#         vertical-align: middle;
#     }
#
#     /* LINK */
#     a {
#         color: #FF8000;
#     }
#
#     /* H1 */
#     h1 {
#         font-size: 42px !important;
#         text-align: center;
#         color: #FF8000;
#     }
#
#     /* H2 */
#     h2 {
#         font-size: 32px !important;
#     }
#
#     /* H2 */
#     h3 {
#         font-size: 24px !important;
#     }
#
#     /* H2 */
#     h4 {
#         font-size: 20px !important;
#     }
#
#     /* PARAGRAPH */
#     p {
#         font-size: 16px !important;
#         text-align: center;
#     }
#
#     /* LIST ITEM */
#     li {
#         font-size: 16px !important;
#     }
#
# </style>

# %% [markdown]
# # The static picture of Stack Overflow tags
#
# Fetching all tags from the StackOverflow API
#
# ### NOTES
# ---
#
# * Synonyms tags have same counts as mother tag (checked from website) and when tags are requested, the mother tag is retrieved (so in the DF below we have mother tags and the global usage of it plus its synonyms)
# * There are roughly a total of 55k tags on SO

# %% [markdown]
# ## Read data into a dataframe

# %%
df = pd.read_json(data_folder + 'tags_data_backup.json', orient='index')

# %% [markdown]
# ## Manipulate a bit

# %%
# Set some new columns
# * creation date in datetime (from timestamp)
# * subsequent number of days from date of today (age)
# * number of sysnonyms

df['creation_date_date'] = df['creation_date'].apply(datetime.fromtimestamp)
df['age'] = (datetime.today() - df['creation_date_date']).dt.days
df['num_synonyms'] = df['synonyms'].apply(len)

# %% [markdown]
# ## A few starting stats and info

# %%
df.head()
# Out:
#             count  creation_date  has_synonyms  is_moderator_only  \
# .htaccess   60983     1218010528             1                  0
# .net       262711     1217547659             1                  0
# .net-3.5     5785     1217566773             1                  0
# .net-4.0     8592     1222697573             1                  0
# .net-core    6029     1314097465             1                  0
#
#            is_required       name                           synonyms  \
# .htaccess            0  .htaccess                         [htaccess]
# .net                 0       .net  [.net-framework, dot-net, dotnet]
# .net-3.5             0   .net-3.5               [.net-framework-3.5]
# .net-4.0             0   .net-4.0        [.net-framework-4.0, .net4]
# .net-core            0  .net-core          [dotnetcore, dotnet-core]
#
#            creation_date_date   age  num_synonyms
# .htaccess 2008-08-06 09:15:28  3444             1
# .net      2008-08-01 00:40:59  3450             3
# .net-3.5  2008-08-01 05:59:33  3450             1
# .net-4.0  2008-09-29 15:12:53  3390             2
# .net-core 2011-08-23 12:04:25  2332             2

# %%
df.describe()
df.corr()
# Out:
#               count  creation_date  has_synonyms  is_moderator_only  \
# count  1.000000e+03   1.000000e+03    1000.00000             1000.0
# mean   3.382785e+04   1.236501e+09       0.60200                0.0
# std    1.097497e+05   4.096053e+07       0.48973                0.0
# min    5.331000e+03   1.217541e+09       0.00000                0.0
# 25%    7.264750e+03   1.217995e+09       0.00000                0.0
# 50%    1.166550e+04   1.219364e+09       1.00000                0.0
# 75%    2.376775e+04   1.225131e+09       1.00000                0.0
# max    1.539243e+06   1.456536e+09       1.00000                0.0
#
#        is_required          age  num_synonyms
# count       1000.0  1000.000000   1000.000000
# mean           0.0  3230.419000      1.368000
# std            0.0   474.097722      2.202141
# min            0.0   684.000000      0.000000
# 25%            0.0  3362.000000      0.000000
# 50%            0.0  3429.000000      1.000000
# 75%            0.0  3445.000000      2.000000
# max            0.0  3450.000000     29.000000
#                       count  creation_date  has_synonyms  is_moderator_only  \
# count              1.000000      -0.077774      0.130861                NaN
# creation_date     -0.077774       1.000000     -0.165142                NaN
# has_synonyms       0.130861      -0.165142      1.000000                NaN
# is_moderator_only       NaN            NaN           NaN                NaN
# is_required             NaN            NaN           NaN                NaN
# age                0.077774      -1.000000      0.165131                NaN
# num_synonyms       0.433632      -0.130703      0.505361                NaN
#
#                    is_required       age  num_synonyms
# count                      NaN  0.077774      0.433632
# creation_date              NaN -1.000000     -0.130703
# has_synonyms               NaN  0.165131      0.505361
# is_moderator_only          NaN       NaN           NaN
# is_required                NaN       NaN           NaN
# age                        NaN  1.000000      0.130703
# num_synonyms               NaN  0.130703      1.000000

# %%
# who are the oldest tags and when from
df.sort_values('creation_date', ascending=True).head()

# who's the ones with most sysnonyms
df.sort_values('num_synonyms', ascending=False).head()
# Out:
#                    count  creation_date  has_synonyms  is_moderator_only  \
# type-conversion     8356     1217540572             1                  0
# winforms           78063     1217540572             1                  0
# c#               1170433     1217540572             1                  0
# css               514186     1217542088             1                  0
# html              718115     1217542088             1                  0
#
#                  is_required             name  \
# type-conversion            0  type-conversion
# winforms                   0         winforms
# c#                         0               c#
# css                        0              css
# html                       0             html
#
#                                                           synonyms  \
# type-conversion             [typeconverting, data-type-conversion]
# winforms         [windows.forms, winform, window-form, windows-...
# c#               [.cs-file, csharp, visual-c#, c#-language, c#....
# css              [css-font-weight, dynamic-css, css-borders, cs...
# html             [span, html-comments, div-layouts, nested-divs...
#
#                  creation_date_date   age  num_synonyms
# type-conversion 2008-07-31 22:42:52  3450             2
# winforms        2008-07-31 22:42:52  3450             6
# c#              2008-07-31 22:42:52  3450             6
# css             2008-07-31 23:08:08  3450            29
# html            2008-07-31 23:08:08  3450             8
#                count  creation_date  has_synonyms  is_moderator_only  \
# css           514186     1217542088             1                  0
# performance    74456     1217568082             1                  0
# php          1157797     1217595018             1                  0
# uitableview    55156     1222271666             1                  0
# javascript   1539243     1217551358             1                  0
#
#              is_required         name  \
# css                    0          css
# performance            0  performance
# php                    0          php
# uitableview            0  uitableview
# javascript             0   javascript
#
#                                                       synonyms  \
# css          [css-font-weight, dynamic-css, css-borders, cs...
# performance  [slow-load, code-efficiency, performance-monit...
# php          [php-include, phtml, php-fpm, php-session, php...
# uitableview  [tableviewcell, uitableviewcelll, uitableviewc...
# javascript   [javascript-module, vanilla-javascript, javasc...
#
#              creation_date_date   age  num_synonyms
# css         2008-07-31 23:08:08  3450            29
# performance 2008-08-01 06:21:22  3450            23
# php         2008-08-01 13:50:18  3449            16
# uitableview 2008-09-24 16:54:26  3395            14
# javascript  2008-08-01 01:42:38  3450            12

# %% [markdown]
# ## Usage counts, distribution and Zipf

# %%
# Usage of the first 20 tags: bar plot

df.sort_values('count', ascending=False).head(20).plot('name', 'count', kind='barh', color=plot_color)
plt.title('The first 20 tags in usage')
plt.ylabel('Tag name')
plt.xlabel('Usage count')
plt.gca().invert_yaxis()
plt.legend().set_visible(False)
plt.xkcd()
plt.show();

# %%
df_tmp = df.sort_values('count', ascending=False)

plt.xkcd()
plt.semilogy(range(df.count()['name']), df_tmp['count'], color=plot_color)
plt.title('Usage counts of all tags')
plt.ylabel('Usage count')
plt.xlabel('Rank')
plt.grid(True, linewidth=1)
plt.minorticks_on()
plt.show();

# %%
# Histogram usage of tags

df.hist('count', bins=50, log=True, color=plot_color, zorder=3)
plt.title('Histogram of tag usage')
plt.xlabel('Usage count')
plt.ylabel('Number of tags')
plt.xkcd()
plt.grid(True, linewidth=1, linestyle='dashed', zorder=0)
plt.show();

# %%
## Fit the frequency-rank data

x = [i for i in range(df.count()['name'])]
y = list(df.sort_values('count', ascending=False)['count'])
p_fit = fit_powlaw(x, y, start=10)
print('Exponent is ', p_fit[0][1])
# Out:
# ('Exponent is ', -0.96644210866076818)

# %%
# Frequency-rank in log-log (Zipf), plus the fit

plt.loglog([i for i in range(df.count()['name'])], list(df.sort_values('count', ascending=False)['count']), 
           color=plot_color, label='points')
plt.loglog(x[11:], 10**p_fit[0][0] * x[11:]** p_fit[0][1], label='fit', color='k', linestyle='dashed')
plt.title('Frequency-rank plot of tags')
plt.xlabel('Rank')
plt.ylabel('Usage')
plt.xkcd()
plt.grid(True, linewidth=1, linestyle='dashed', zorder=0)
plt.show();

# %%
plt.plot(np.log10(x), p_fit[0][0] + p_fit[0][1] * np.log10(x))
plt.plot(np.log10(x[11:]), np.log10(y[11:]))
plt.grid()
plt.show();
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':

# %% [markdown]
# ## Age

# %%
df[df['age'] < 3200].plot('age', 'count', kind='scatter')
plt.show();

# %%
df[(df['age'] < 3200) & (df['count'] > 150000)]
# Out:
#             count  creation_date  has_synonyms  is_moderator_only  \
# angularjs  247601     1255952507             1                  0
# swift      176984     1296795306             1                  0
#
#            is_required       name                               synonyms  \
# angularjs            0  angularjs               [angular1.x, angular.js]
# swift                0      swift  [swift1.2, swift-ios, swift-language]
#
#            creation_date_date   age  num_synonyms
# angularjs 2009-10-19 12:41:47  3005             2
# swift     2011-02-04 04:55:06  2532             3

# %%
df[df['creation_date_date'] < datetime(2009,1,1)].plot('creation_date_date', 'count')
plt.show();

# %% [markdown]
# ## Synonyms

# %%
df.plot('num_synonyms', 'count', kind='scatter')

for i, txt in enumerate(n):
    plot.annotate(txt, (z[i],y[i]))

plt.show();

# %%
df.groupby('has_synonyms').mean()
# Out:
#                      count  creation_date  is_moderator_only  is_required  \
# has_synonyms
# 0             16173.472362   1.244816e+09                0.0          0.0
# 1             45499.682724   1.231004e+09                0.0          0.0
#
#                       age  num_synonyms
# has_synonyms
# 0             3133.871859      0.000000
# 1             3293.709302      2.272425

# %%
df[df['has_synonyms'] == 0].head()
# Out:
#                   count  creation_date  has_synonyms  is_moderator_only  \
# access-vba         9184     1221554416             0                  0
# actionscript       9052     1219352512             0                  0
# active-directory  10779     1217762514             0                  0
# activerecord      24601     1218468630             0                  0
# admob              6416     1239466740             0                  0
#
#                   is_required              name synonyms  creation_date_date  \
# access-vba                  0        access-vba       [] 2008-09-16 09:40:16
# actionscript                0      actionscript       [] 2008-08-21 22:01:52
# active-directory            0  active-directory       [] 2008-08-03 12:21:54
# activerecord                0      activerecord       [] 2008-08-11 16:30:30
# admob                       0             admob       [] 2009-04-11 17:19:00
#
#                    age  num_synonyms
# access-vba        3403             0
# actionscript      3429             0
# active-directory  3447             0
# activerecord      3439             0
# admob             3196             0
