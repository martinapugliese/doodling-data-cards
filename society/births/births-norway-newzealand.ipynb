# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib 

# %matplotlib inline

# %% [markdown]
# ## Get data and manioulate
#
# Data is downloaded from the UN databases, live birth table, http://data.un.org/Data.aspx?q=births&d=POP&f=tableCode%3a55

# %%
df = pd.read_csv('UNdata_Export_20180610_090813198.csv')

# %%
df.head()
# Out:
#   Country or Area  Year   Area     Month  \
# 0         Finland  2015  Total     Total
# 1         Finland  2015  Total   January
# 2         Finland  2015  Total  February
# 3         Finland  2015  Total     March
# 4         Finland  2015  Total     April
#
#                             Record Type             Reliability  Source Year  \
# 0  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 1  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 2  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 3  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 4  Data tabulated by year of occurrence  Final figure, complete       2017.0
#
#      Value  Value Footnotes
# 0  55472.0              NaN
# 1   4659.0              NaN
# 2   4209.0              NaN
# 3   4603.0              NaN
# 4   4629.0              NaN

# %%
df['Country or Area'].unique()
# Out:
# array(['Finland', 'New Zealand', 'Norway', 'footnoteSeqID', '1'],
#       dtype=object)

# %%
## only select Norway and New Zealand (want to compare these two)

df = df[df['Country or Area'].isin(['Norway', 'New Zealand'])]

# %%
df[df['Country or Area'] == 'New Zealand'].head()
# Out:
#    Country or Area  Year   Area     Month  \
# 13     New Zealand  2015  Total     Total
# 14     New Zealand  2015  Total   January
# 15     New Zealand  2015  Total  February
# 16     New Zealand  2015  Total     March
# 17     New Zealand  2015  Total     April
#
#                                Record Type             Reliability  \
# 13  Data tabulated by year of registration  Final figure, complete
# 14  Data tabulated by year of registration  Final figure, complete
# 15  Data tabulated by year of registration  Final figure, complete
# 16  Data tabulated by year of registration  Final figure, complete
# 17  Data tabulated by year of registration  Final figure, complete
#
#     Source Year    Value  Value Footnotes
# 13       2017.0  61038.0              1.0
# 14       2017.0   4962.0              1.0
# 15       2017.0   4587.0              1.0
# 16       2017.0   4962.0              1.0
# 17       2017.0   4866.0              1.0

# %%
# store aside and remove row for totals
tot_norway = list(df[(df['Country or Area'] == 'Norway') & (df['Month'] == 'Total')]['Value'])[0]
tot_nz = list(df[(df['Country or Area'] == 'New Zealand') & (df['Month'] == 'Total')]['Value'])[0]

df = df[df['Month'] != 'Total']
df = df[df['Month'] != 'Unknown']

df_norway = df[df['Country or Area'] == 'Norway']
df_nz = df[df['Country or Area'] == 'New Zealand']

tot_norway, tot_nz
# Out:
# (58815.0, 61038.0)

# %%
## Add col for the bith monhts / totals

df_norway['month_rate'] = df_norway['Value'] / tot_norway
df_nz ['month_rate'] = df_nz['Value'] / tot_nz
# Out:
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_norway
# Out:
#    Country or Area  Year   Area      Month  \
# 27          Norway  2015  Total    January
# 28          Norway  2015  Total   February
# 29          Norway  2015  Total      March
# 30          Norway  2015  Total      April
# 31          Norway  2015  Total        May
# 32          Norway  2015  Total       June
# 33          Norway  2015  Total       July
# 34          Norway  2015  Total     August
# 35          Norway  2015  Total  September
# 36          Norway  2015  Total    October
# 37          Norway  2015  Total   November
# 38          Norway  2015  Total   December
#
#                              Record Type             Reliability  Source Year  \
# 27  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 28  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 29  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 30  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 31  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 32  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 33  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 34  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 35  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 36  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 37  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 38  Data tabulated by year of occurrence  Final figure, complete       2017.0
#
#      Value  Value Footnotes  month_rate
# 27  4760.0              NaN    0.080932
# 28  4497.0              NaN    0.076460
# 29  4759.0              NaN    0.080915
# 30  5113.0              NaN    0.086934
# 31  5261.0              NaN    0.089450
# 32  5386.0              NaN    0.091575
# 33  5630.0              NaN    0.095724
# 34  5304.0              NaN    0.090181
# 35  4951.0              NaN    0.084179
# 36  4800.0              NaN    0.081612
# 37  4202.0              NaN    0.071444
# 38  4152.0              NaN    0.070594

# %%
df_nz
# Out:
#    Country or Area  Year   Area      Month  \
# 14     New Zealand  2015  Total    January
# 15     New Zealand  2015  Total   February
# 16     New Zealand  2015  Total      March
# 17     New Zealand  2015  Total      April
# 18     New Zealand  2015  Total        May
# 19     New Zealand  2015  Total       June
# 20     New Zealand  2015  Total       July
# 21     New Zealand  2015  Total     August
# 22     New Zealand  2015  Total  September
# 23     New Zealand  2015  Total    October
# 24     New Zealand  2015  Total   November
# 25     New Zealand  2015  Total   December
#
#                                Record Type             Reliability  \
# 14  Data tabulated by year of registration  Final figure, complete
# 15  Data tabulated by year of registration  Final figure, complete
# 16  Data tabulated by year of registration  Final figure, complete
# 17  Data tabulated by year of registration  Final figure, complete
# 18  Data tabulated by year of registration  Final figure, complete
# 19  Data tabulated by year of registration  Final figure, complete
# 20  Data tabulated by year of registration  Final figure, complete
# 21  Data tabulated by year of registration  Final figure, complete
# 22  Data tabulated by year of registration  Final figure, complete
# 23  Data tabulated by year of registration  Final figure, complete
# 24  Data tabulated by year of registration  Final figure, complete
# 25  Data tabulated by year of registration  Final figure, complete
#
#     Source Year   Value  Value Footnotes  month_rate
# 14       2017.0  4962.0              1.0    0.081294
# 15       2017.0  4587.0              1.0    0.075150
# 16       2017.0  4962.0              1.0    0.081294
# 17       2017.0  4866.0              1.0    0.079721
# 18       2017.0  4917.0              1.0    0.080556
# 19       2017.0  4746.0              1.0    0.077755
# 20       2017.0  4992.0              1.0    0.081785
# 21       2017.0  4920.0              1.0    0.080606
# 22       2017.0  5022.0              1.0    0.082277
# 23       2017.0  5364.0              1.0    0.087880
# 24       2017.0  5685.0              1.0    0.093139
# 25       2017.0  6012.0              1.0    0.098496

# %%
df_norway['month_rate'].sum()
df_nz['month_rate'].sum()
# Out:
# 0.9999508502899834

# %% [markdown]
# ## Plot birth rate per month

# %%
ax = df_norway.plot('Month', 'month_rate', marker='o', label='Norway', figsize=(15, 6))
df_nz.plot('Month', 'month_rate', marker='o', ax=ax, label='New Zealand')

#plt.ylim([0, 0.1])

plt.ylabel('Month births / total births')
plt.grid()
plt.xticks(range(12), df_norway.Month, rotation=70)
plt.show();
